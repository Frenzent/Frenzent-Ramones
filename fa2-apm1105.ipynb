# %% [markdown]
# ## **2. Write a function that draws a grid like the following**

# %%
def draw_grid():
    print('[]','=','=','=','=','[]','=','=','=','=','[]','=','=','=','=','[]','=','=','=','=','[]')
    print('||',' ',' ',' ',' ','||',' ',' ',' ',' ','||',' ',' ',' ',' ','||',' ',' ',' ',' ','||')
    print('||',' ',' ',' ',' ','||',' ',' ',' ',' ','||',' ',' ',' ',' ','||',' ',' ',' ',' ','||')
    print('||',' ',' ',' ',' ','||',' ',' ',' ',' ','||',' ',' ',' ',' ','||',' ',' ',' ',' ','||')
    print('||',' ',' ',' ',' ','||',' ',' ',' ',' ','||',' ',' ',' ',' ','||',' ',' ',' ',' ','||')

# Call the function to draw the grid
draw_grid()
draw_grid()
draw_grid()
draw_grid()


def draw_grid_1():
    print('[]','=','=','=','=','[]','=','=','=','=','[]','=','=','=','=','[]','=','=','=','=','[]')
draw_grid_1()
# Out:
# [] = = = = [] = = = = [] = = = = [] = = = = []
# ||         ||         ||         ||         ||
# ||         ||         ||         ||         ||
# ||         ||         ||         ||         ||
# ||         ||         ||         ||         ||
# [] = = = = [] = = = = [] = = = = [] = = = = []
# ||         ||         ||         ||         ||
# ||         ||         ||         ||         ||
# ||         ||         ||         ||         ||
# ||         ||         ||         ||         ||
# [] = = = = [] = = = = [] = = = = [] = = = = []
# ||         ||         ||         ||         ||
# ||         ||         ||         ||         ||
# ||         ||         ||         ||         ||
# ||         ||         ||         ||         ||
# [] = = = = [] = = = = [] = = = = [] = = = = []
# ||         ||         ||         ||         ||
# ||         ||         ||         ||         ||
# ||         ||         ||         ||         ||
# ||         ||         ||         ||         ||
# ...
